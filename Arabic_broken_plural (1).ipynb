# %%
from camel_tools.morphology.database import MorphologyDB
from camel_tools.morphology.analyzer import Analyzer

db = MorphologyDB.builtin_db()

# Create analyzer with no backoff
analyzer = Analyzer(db)

# To analyze a word, we can use the analyze() method
#analyses = analyzer.analyze('$AriE_1')
#print(analyses)
print(db)

# %%
import csv
def get_bw_words():
    with open('C:/Users/19061/Downloads/Arabic_words.csv', encoding="utf-8-sig", newline='') as f:
        reader = csv.reader(f)
        return [word[0][1:-3] for word in list(reader)]
bw_ls = get_bw_words()

# %%
from camel_tools.utils.charmap import CharMapper
from camel_tools.utils.transliterate import Transliterator

# We will transliterate from Buckwalter encoding to Arabic script
ar_ls = []
for word in bw_ls:
    bw2ar = CharMapper.builtin_mapper('bw2ar')
    bw2ar_trans = Transliterator(bw2ar)
    # This will remove the markers in the output
    transliterated_no_mark = bw2ar_trans.transliterate(word, True)
    ar_ls.append(transliterated_no_mark)
#print(len(ar_ls))

# %%
from camel_tools.morphology.database import MorphologyDB
from camel_tools.morphology.generator import Generator
from camel_tools.utils.charmap import CharMapper
from camel_tools.utils.transliterate import Transliterator
def get_noun_plural_form(lemma):
    # Initialize database in generation mode
    db = MorphologyDB.builtin_db(flags='g')

    # Create generator instance
    generator = Generator(db)

    # Specify lemma and features to generate for
    features = {    
        'pos': 'noun', 
        'num': 'p'
        #'form_num': 'p',
        #'form_gen': 'm',    # 0%
        #'cas': 'u'
    }
    # Generate analyses for lemma and features
    analyses = generator.generate(lemma, features)
    
    # transliterate from Arabic script to Buckwalter encoding
    ar2bw = CharMapper.builtin_mapper('ar2bw')
    ar2bw_trans = Transliterator(ar2bw)
    
    #return all the Buckwater plural forms and form_gender for each Arabic word 
    ls = []
    for i in analyses:
        for key, value in i.items():
            record = [ar2bw_trans.transliterate(i['diac'], True), i['form_gen']]
            ls.append(record)
            #ls.append(ar2bw_trans.transliterate(i['diac'], True))
    return ls

def check_noun_broken_plural(n):
    regular = 0
    empty = 0
    regn_ls = []
    empty_ls = []
    for word in bw_ls[0:int(n)]:
        bw2ar = CharMapper.builtin_mapper('bw2ar')
        bw2ar_trans = Transliterator(bw2ar)
        # This will remove the markers in the output
        ar_wd = bw2ar_trans.transliterate(word, True)
        plurals = get_noun_plural_form(ar_wd)
        print(word, plurals)
        if len(plurals) == 0:
            empty += 1
            empty_ls.append(word)
        if any (word == p[0][0:-2] and (p[0][-2:] == 'At' or p[0][-4:] == 'uwna' or p[0][-3:] == 'wna' or p[0][-2:] == 'wn' or p[0][-2:] == 'uw') for p in plurals):
            regn_ls.append(word)
            regular += 1    
    ratio = int(regular) / int(n)
    print(int(empty))   #64   579    num:p1000:338 230/662
    print(regn_ls)
    print(empty_ls)
    #['ra}iys', '>amoriykiy~', 'filasoTiyniy~', 'waziyr', '<isorA}iyliy~', 'siyAsiy~', 'EirAqiy~', 'lubonAniy~', 'qarAr', 
    #'<isolAmiy~', 'Easokariy~', 'miSoriy~', 'nA}ib', 'duwlAr', 'ma$oruwE', 'salAm', 'maso&uwl', 'mu&otamar', 'Eabod']
    print(f"Percentage of regular plurals in the most frequent {n} words: {int(ratio * 100)}%.")
check_noun_broken_plural(100)    # 19/36    # 23%    230/421
# Out:
from camel_tools.morphology.database import MorphologyDB
from camel_tools.morphology.generator import Generator
from camel_tools.utils.charmap import CharMapper
from camel_tools.utils.transliterate import Transliterator
def get_adj_plural_form(lemma):
    # Initialize database in generation mode
    db = MorphologyDB.builtin_db(flags='g')

    # Create generator instance
    generator = Generator(db)
    
    # Specify lemma and features to generate for
    features = {    
        'pos': 'adj', 
        'num': 'p'
        #'form_num': 'p',
        #'cas': 'u'
    }
    # Generate analyses for lemma and features
    analyses = generator.generate(lemma, features)
    
    # transliterate from Arabic script to Buckwalter encoding
    ar2bw = CharMapper.builtin_mapper('ar2bw')
    ar2bw_trans = Transliterator(ar2bw)
    
    #return all the Buckwater plural forms and form_gender for each Arabic word 
    ls = []
    for i in analyses:
        for key, value in i.items():
            record = [ar2bw_trans.transliterate(i['diac'], True), i['form_gen']]
            ls.append(record)
            #ls.append(ar2bw_trans.transliterate(i['diac'], True))
    return ls

def check_adj_broken_plural(n):
    regular = 0
    empty = 0
    rega_ls = []
    empty_ls = []
    for word in bw_ls[800:int(n)]:
        bw2ar = CharMapper.builtin_mapper('bw2ar')
        bw2ar_trans = Transliterator(bw2ar)
        # This will remove the markers in the output
        ar_wd = bw2ar_trans.transliterate(word, True)
        plurals = get_adj_plural_form(ar_wd)
        print(word, plurals)
        if len(plurals) == 0:
            empty += 1
            empty_ls.append(word)
        #if any (word == p[0][0:-2] and (p[0][-2:] == 'At' or p[0][-4:] == 'uwna' or p[0][-3:] == 'wna' or p[0][-2:] == 'wn' or p[0][-2:] == 'uw') for p in plurals):
        if any ((p[0] == word + 'At' or p[0] == word + 'uwna' or p[0] == word + 'wna' or p[0] == word + 'wn' or p[0] == word + 'uw') for p in plurals):
            regular += 1
            rega_ls.append(word)
    ratio = int(regular) / int(n)
    print(int(empty)) #79   #859    856 130/144
    print(rega_ls)
    print(empty_ls)
    #['>amoriykiy~', 'filasoTiyniy~', 'Earabiy~', '<isorA}iyliy~', '>aw~al', 'siyAsiy~', 'EirAqiy~', 'jadiyd', 'mut~aHid', 
    #'lubonAniy~', '<isolAmiy~', 'xArijiy~', 'vAniy', 'miSoriy~', 'mADiy', 'waTaniy~', '>amoniy~', 'sAbiq', 
    #'|xar', 'maso&uwl', '>axiyr']
    print(f"Percentage of regular plurals in the most frequent {n} words: {int(ratio * 100)}%.")
check_adj_broken_plural(1000)  

# 21/21   13%   、130/141
# Out:
# qA}im [['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtu', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], ['qA}imAtN', 'f'], 
'xabiyr', 'tamowiyl', 'ta>omiyn', 'dibluwmAsiy~', 'SaHiyH', 'biloyuwn', '>ayoluwl', 'tarAjuE', 'manoSib', '$Amil', "warA'", '{iHotimAl', 'maboda>', '{igotiyAl', 'junayoh', 'niqAbap', 'marokaz', 'taqad~um', 'muwAfaqap', 'Darobap', 'Sawot', "kahorabA'", '>uwrub~A', '$awoT', 'qADiy', 'sumuw~', 'lAji}', 'kuwriyA', 'nATiq', 'jaziyrap', 'juroH', 'jid~', '>amiyr', 'maEorakap', 'muEoZam', 'laHuwd', 'fasAd', 'diyn', 'funoduq', 'Eayon', 'mamolakap', 'Had~', 'qaroyap', 'TabiyEiy~', 'xuruwj', 'faSiyl', '$ab~', 'fikor', 'Siyn', '{ivonayoni', 'fan~iy~', 'munAqa$ap', 'ragobap', 'Sawot', 'muwsaY', "sawA'", 'Eaduw~', 'qAdim', 'SaEob', 'mukAfaHap', 'SaHAfiy~', 'kalAm', 'riyAD', 'bayoE', 'Zuhor', '{iHotifAl', 'bArAk', 'taEobiyr', 'vaqAfap', '<inotAj', 'sijon', '>avar', 'baTal', 'taHAluf', "Dawo'", '{isotiEodAd', 'muwaZ~af', '<isotrAtiyjiy~ap', '{isotiqolAl', 'nizAE', 'sibotamobar', 'xayor', 'laHoZap', 'sibAq', 'siyAdap', '$ak~', 'say~idap', 'bAb', 'sit~uwn', 'sayoTarap', '$axoSiy~ap', 'zamiyl', 'mumArasap', 'xamiys', 'tawoqiyE', 'xaTa>', 'yAsir', 'niZAm', 'mu&ak~id', 'mu&a$~ir', 'tawaj~uh', 'rAyos', 'siwaY', 'qalaq', ">avonA'a", 'viqap', 'mu$Ahid', 'mubArak', 'bAkisotAn', 'mutaHad~iv', 'gAlibiy~ap', "<ino$A'", 'muHAkamap', '>aboyaD', 'ta>oviyr', 'kliynotuwn', "$irA'", 'maqoEad', 'riEAyap', 'taZAhurap']

print(len(set(ls1 + ls2))) 

common = []
for i in ls3:
    if i in ls4:
        common.append(i)
print(len(common))
# Out:
# 101
# 81

# %%
regn_ls = ['ra}iys', '>amoriykiy~', 'filasoTiyniy~', 'waziyr', '<isorA}iyliy~', 'siyAsiy~', 'EirAqiy~', 'lubonAniy~', 'qarAr', 
           '<isolAmiy~', 'Easokariy~', 'miSoriy~', 'nA}ib', 'duwlAr', 'ma$oruwE', 'salAm', 'maso&uwl', 'mu&otamar', 'Eabod']
rega_ls = ['>amoriykiy~', 'filasoTiyniy~', 'Earabiy~', '<isorA}iyliy~', '>aw~al', 'siyAsiy~', 'EirAqiy~', 'jadiyd', 'mut~aHid', 
            'lubonAniy~', '<isolAmiy~', 'xArijiy~', 'vAniy', 'miSoriy~', 'mADiy', 'waTaniy~', '>amoniy~', 'sAbiq', '|xar', 
           'maso&uwl', '>axiyr'] 

print(len(set(regn_ls2 + rega_ls2)))      # 31   314   314
# Out:
# 314

# %%
#form_num=p 100
emp_lsn = ['maE', 'yawom', 'bayona', 'dawolap', 'Earabiy~', 'baEod', 'kul~', '>aw~al', 'minoTaqap', 'EirAq', 'Eamal', 'majolis', 
          'jadiyd', 'EAm', 'lubonAn', 'xilAl', 'mut~aHid', 'EAm~', 'All~`h', '>ay~', '<isorA}iyl', 'balad', 'baEoD', 'duwaliy~',
          'gayor', '>alof', '>amon', '$aEob', 'kabiyr', 'Eadad', 'Hizob', 'qabol', '|n', 'xArijiy~', '>uxoraY', 'vAniy', 'mADiy',
          'waTaniy~', '>amor', '>amAm', '>amoniy~', 'madiynap', 'Haq~', 'hadaf', 'qaDiy~ap', 'waDoE', '>amos', 'nafos', '$a>on',
          'mawoqif', 'qAnuwn', 'Harob', 'waqot', '>akovar', 'sAbiq', '>aroD', '', 'jAnib', '>axiyr', 'sabab', 'Did~', '<iyrAn',
          '>aHad', 'maSodar']
emp_lsa = ['maE', 'ra}iys', 'yawom', 'bayona', 'dawolap', 'waziyr', 'baEod', 'kul~', 'Hukuwmap', 'quw~ap', 'minoTaqap', 'EirAq',
            'Eamaliy~ap', 'Eamal', 'majolis', 'EAm', 'lubonAn', 'xilAl', 'EAm~', 'All~`h', '>ay~', '<isorA}iyl', 'balad', 
            'baEoD', 'duwaliy~', 'gayor', 'wilAyap', '>alof', 'qarAr', '>amon', '$aEob', 'kabiyr', 'Eadad', 'Hizob', 'qabol', 
            '|n', 'sanap', 'valAv', 'Easokariy~', 'Harakap', 'nA}ib', 'suloTap', 'mi}ap', '{inotixAb', 'EAlam', 'wizArap', 
            '>amor', '>amAm', 'duwlAr', 'madiynap', 'Haq~', 'ma$oruwE', 'hadaf', '$arikap', 'qaDiy~ap', 'waDoE', 'salAm', 
            '>amos', 'nafos', '$a>on', 'mawoqif', 'qAnuwn', 'Harob', 'lajonap', 'waqot', '>akovar', '>aroD', '', 'jAnib', 
            'EalAqap', '{it~ifAq', 'sabab', 'Did~', '<iyrAn', '>aHad', 'mu&otamar', '{iqotiSAdiy~', 'maSodar', 'Eabod']

#form_num=p 1000
emp_lsn1 = ['maE', 'yawom', 'bayona', 'dawolap', 'Earabiy~', 'baEod', 'kul~', '>aw~al', 'minoTaqap', 'EirAq', 'Eamal', 'majolis', 'jadiyd', 'EAm', 'lubonAn', 'xilAl', 'mut~aHid', 'EAm~', 'All~`h', '>ay~', '<isorA}iyl', 'balad', 'baEoD', 'duwaliy~', 'gayor', '>alof', '>amon', '$aEob', 'kabiyr', 'Eadad', 'Hizob', 'qabol', '|n', 'xArijiy~', '>uxoraY', 'vAniy', 'mADiy', 'waTaniy~', '>amor', '>amAm', '>amoniy~', 'madiynap', 'Haq~', 'hadaf', 'qaDiy~ap', 'waDoE', '>amos', 'n
n', "$irA'", 'maqoEad', 'riEAyap', 'taZAhurap', 'jAmiEap', 'buEod', 'SaHAfiy~', 'murAsil', 'fiylom', 'kaviyr', 'waraq', 'laqab', 'Saf~', 'tamAm', 'maloEab', 'sifArap', "<inohA'", 'rAm', 'tasoliym', 'faDol', '{iHotijAj', 'baHor', 'musota$Ar', 'qAEidap', 'jA}izap', 'tarotiyb', 'jariyH', 'lA}iHap', 'suquwT', '{inotiZAr', '{i$otibAk', '$ayox', 'jalAlap', 'Sagiyr', 'mu$Arik', 'badal', 'munAfasap', 'lugap', 'yuwsif', 'maEoriD', '<iyjAd', 'EAliy', 'buwroSap', 'Eaqod', "{inotihA'", 'tadoriyb', 'nahAr', 'mabolag', '{it~ifAqiy~ap', 'muTAlabap', 'tanosiyq', ">adA'", 'muHAfiZ', 'tafojiyr', 'kiyluwmitr', 'SiH~iy~', 'siyAHap', 'mabonaY', 'yawomiy~', 'nAHiyap', 'fa$al', 'giyAb', 'tawoziyE', 'ta$oriyEiy~', 'qaDA}iy~', '<irosAl', 'vamAnuwn', 'taSoEiyd', 'TabiyEap', 'xitAm', '<iEodAd', 'tawat~ur', 'HiSAr', '$axoSiy~', 'qiyAdap', '{isotiqobAl', 'jazA}ir', '>uwlomirt', 'magorib', 'mudar~ib', 'xiyAr', 'naSor', 'diyn', 'tajam~uE', 'qalob', 'maSorafiy~', 'taqoriyr', 'EudowAn', 'Hukom', 'kuwnojris', 'saboEuwn', 'ta>oyiyd', 'waviyqap', 'DAbiT', 'tawojiyh', 'TAlibAn', 'ruwH', 'tarobiyap', '>asad', '>usoluwb', 'muEad~al', 'qabuwl', '{iqotirAH', 'rukon', '<iDAfiy~', 'Eadol', 'tanofiy*iy~', 'HisAb', 'tawofiyr', 'Safoqap', 'raSiyd', '{inoxifAD', 'fAriq', 'tisoEuwn', 'fi}ap', '>alomAniyA', 'ka$of', 'mubA$arap', 'murAqib', 'gAz', 'layol', '<i*AEap', 'HawAlay', '>aHomar', 'niy~ap', '{isotixobAr', '{iEotirAf', 'Hilof', 'mujar~ad', 'numuw~', 'Sifor', 'musAEid', 'yAbAn', 'tawoqiyt', 'qaTar', 'maHal~', 'naHow', 'qaron', '|*Ar', 'SuwmAl', 'Eumolap', 'lAHiq', 'SinAEiy~', 'Eumor', 'Haliyf', 'naZiyr', 'SaHAfap', 'dayon', 'daliyl', 'jazol', 'Sadiyq', '>asoyA', 'dAxiliy~ap', 'musotavomir', 'TaroH', '<inoqA*', 'muHotal~', 'Dayof', 'tuhomap', "nisA'", '{inoti$Ar', 'Sunoduwq', '{isoti}onAf', '{ifotitAH', 'taEowiyD', 'kam~iy~ap', 'taqoriyb', 'taSowiyt', 'Sarof', 'SalAp', '|liy~ap', 'masAr', 'qA}imap', 'laEob', '|l']
common = []
for i in emp_lsn2:
    if i in emp_lsa2:
        common.append(i)
print(len(common))    # 52 (31/48= 64.58%)    485 (314/515 = 60.97%)   257  (314/743 = 42.26%)
# Out:
# 257

# %%
from camel_tools.morphology.database import MorphologyDB
from camel_tools.morphology.generator import Generator
def get_adj_plural_form(lemma):
    # Initialize database in generation mode
    db = MorphologyDB.builtin_db(flags='g')

    # Create generator instance
    generator = Generator(db)

    # Specify lemma and features to generate for
    features = {    
        'pos': 'adj', 
        #'num': 'p'
        'form_num': 'p',
        'form_gen': 'm',
        #'cas': 'u'
    }
    # Generate analyses for lemma and features
    analyses = generator.generate(lemma, features)
    
    # transliterate from Arabic script to Buckwalter encoding
    ar2bw = CharMapper.builtin_mapper('ar2bw')
    ar2bw_trans = Transliterator(ar2bw)
    
    #return all the Buckwater plural forms and form_gender for each Arabic word 
    ls = []
    for i in analyses:
        for key, value in i.items():
            record = [ar2bw_trans.transliterate(i['diac'], True), i['pos'], i['form_gen']]
            ls.append(record)
            #ls.append(ar2bw_trans.transliterate(i['diac'], True))
    return ls

def check_adj_broken_plural(n):
    regular = 0
    empty = 0
    rega_ls = []
    for word in bw_ls[0:(int(n))]:
        bw2ar = CharMapper.builtin_mapper('bw2ar')
        bw2ar_trans = Transliterator(bw2ar)
        # This will remove the markers in the output
        ar_wd = bw2ar_trans.transliterate(word, True)
        plurals = get_adj_plural_form(ar_wd)
        print(word, plurals)
        if len(plurals) == 0:
            empty += 1
        if any ((word == p[0][0:-2] and (p[0][-2:] == 'At' or p[0][-2:] == 'wn')) for p in plurals):
            regular += 1
            rega_ls.append(word)
    ratio = int(regular) / int(n)
    print(int(empty)) #83
    print(rega_ls)  #[]
    print(f"Percentage of regular plurals in the most frequent {n} words: {int(ratio * 100)}%.")
check_adj_broken_plural(100)    # 0%
# Out:
# maE []
# ra}iys []
# ...

# %%
#>amoriykiy~ [['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm']]
l1 = []
l2 = []
ls =[['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm']]
ls1 =[['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~AtN', 'adj', 'f'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~uwna', 'adj', 'm'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~Atu', 'adj', 'f'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~uw', 'adj', 'm'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~Ati', 'adj', 'f'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iy', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~iyna', 'adj', 'm'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~AtK', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amoriykiy~At', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~AtN', 'adj', 'f'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~uwna', 'adj', 'm'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~Atu', 'adj', 'f'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~uw', 'adj', 'm'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~Ati', 'adj', 'f'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iy', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~iyna', 'adj', 'm'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~AtK', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amiyrokiy~At', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~AtN', 'adj', 'f'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~uwna', 'adj', 'm'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~Atu', 'adj', 'f'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~uw', 'adj', 'm'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~Ati', 'adj', 'f'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iy', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~iyna', 'adj', 'm'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~AtK', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amoriykAniy~At', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~AtN', 'adj', 'f'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~uwna', 'adj', 'm'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~Atu', 'adj', 'f'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~uw', 'adj', 'm'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~Ati', 'adj', 'f'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iy', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~iyna', 'adj', 'm'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~AtK', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f'], ['>amiyrokAniy~At', 'adj', 'f']]
for i in ls1:
    l2.append(i[0])
print(set(l2))
print(len(set(l2)))
for i in ls:
    l1.append(i[0])
print(set(l1))
print(len(set(l1)))
# Out:
# {'>amoriykiy~AtN', '>amoriykiy~uwna', '>amiyrokiy~iyna', '>amiyrokiy~Ati', '>amoriykAniy~uwna', '>amoriykAniy~uw', '>amiyrokiy~AtK', '>amoriykAniy~Ati', '>amoriykiy~AtK', '>amiyrokAniy~iy', '>amiyrokiy~Atu', '>amiyrokiy~iy', '>amoriykAniy~iyna', '>amoriykAniy~At', '>amiyrokAniy~Ati', '>amiyrokAniy~At', '>amoriykAniy~iy', '>amiyrokiy~AtN', '>amiyrokAniy~AtK', '>amiyrokAniy~AtN', '>amoriykiy~Ati', '>amiyrokAniy~Atu', '>amiyrokAniy~uwna', '>amiyrokAniy~uw', '>amoriykiy~uw', '>amoriykiy~iy', '>amoriykAniy~AtK', '>amiyrokiy~At', '>amoriykiy~iyna', '>amoriykAniy~AtN', '>amiyrokiy~uwna', '>amoriykiy~Atu', '>amiyrokAniy~iyna', '>amoriykiy~At', '>amiyrokiy~uw', '>amoriykAniy~Atu'}
# 36
# {'>amiyrokAniy~uwna', '>amiyrokAniy~uw', '>amoriykiy~uwna', '>amoriykiy~iy', '>amoriykiy~uw', '>amiyrokiy~iyna', '>amiyrokAniy~iy', '>amoriykiy~iyna', '>amoriykAniy~uw', '>amoriykAniy~uwna', '>amiyrokiy~uwna', '>amiyrokiy~iy', '>amoriykAniy~iyna', '>amiyrokAniy~iyna', '>amiyrokiy~uw', '>amoriykAniy~iy'}
# 16

# %%
from camel_tools.morphology.database import MorphologyDB
from camel_tools.morphology.generator import Generator
from camel_tools.utils.charmap import CharMapper
from camel_tools.utils.transliterate import Transliterator

def get_analyses(lemma):
    # Initialize database in generation mode
    db = MorphologyDB.builtin_db(flags='g')

    # Create generator instance
    generator = Generator(db)

    # Specify lemma and features to generate for
    features = {    
        'pos': 'noun', 
        #'num': 'p'
        'form_num': 'p',
        #'cas': 'u'
    }
    # Generate analyses for lemma and features
    analyses = generator.generate(lemma, features)
    ar2bw = CharMapper.builtin_mapper('ar2bw')
    ar2bw_trans = Transliterator(ar2bw)
    for i in analyses:
        print (i)

for word in bw_ls[0:(int(100)+1)]:
    bw2ar = CharMapper.builtin_mapper('bw2ar')
    bw2ar_trans = Transliterator(bw2ar)
    ar_wd = bw2ar_trans.transliterate(word, True)
    get_analyses(ar_wd)
# Out:
# {'diac': 'رَئِيسات', 'lex': 'رَئِيس_1', 'bw': 'رَئِيس/NOUN+ات/NSUFF_FEM_PL', 'gloss': 'president;head;chairman+[fem.pl.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'u', 'enc0': '0', 'rat': 'r', 'source': 'lex', 'form_gen': 'f', 'form_num': 'p', 'pattern': '1َئِي3ات', 'root': 'ر.#.س', 'catib6': 'NOM', 'ud': 'NOUN', 'd1seg': 'رَئِيسات', 'd1tok': 'رَئِيسات', 'atbseg': 'رَئِيسات', 'd3seg': 'رَئِيسات', 'd2seg': 'رَئِيسات', 'd2tok': 'رَئِيسات', 'atbtok': 'رَئِيسات', 'd3tok': 'رَئِيسات', 'bwtok': 'رَئِيس_+ات', 'pos_lex_logprob': -2.347472, 'caphi': 'r_a_2_ii_s_aa_t', 'pos_logprob': -0.4344233, 'gen': 'f', 'lex_logprob': -2.347472, 'num': 'p', 'stemcat': 'N/ap', 'stem': 'رَئِيس', 'stemgloss': 'president;head;chairman'}
# ...
